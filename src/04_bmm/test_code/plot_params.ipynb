# %%
# load and plot the parameter estimates

require('tidyverse')
# Out:
# Loading required package: tidyverse
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
#
# ✔ ggplot2 3.3.0     ✔ purrr   0.3.4
# ✔ tibble  3.0.1     ✔ dplyr   0.8.5
# ✔ tidyr   0.8.3     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
m1_est <- read_csv("../../../data/sim_m1_estimates.csv")
m2_est <- read_csv("../../../data/sim_m2_estimates.csv")
# Out:
# Parsed with column specification:
# cols(
#   parameter = col_character(),
#   ci_l = col_double(),
#   est = col_double(),
#   ci_h = col_double(),
#   n_eff = col_double(),
#   Rhat = col_double(),
#   fit_params = col_character()
# )
#
# Parsed with column specification:
# cols(
#   parameter = col_character(),
#   ci_l = col_double(),
#   est = col_double(),
#   ci_h = col_double(),
#   n_eff = col_double(),
#   Rhat = col_double(),
#   fit_params = col_character()
# )

# %%
summary(m1_est$Rhat)
summary(m1_est$n_eff)
summary(m2_est$Rhat)
summary(m2_est$n_eff)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#  0.9990  0.9995  1.0000  1.0001  1.0005  1.0019      14
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#    2661    2997    3258    3256    3463    3928      14
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.9992  0.9998  1.0002  1.9424  1.6539 13.0715
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    2.012    3.180 3999.943 2796.924 4910.230 5907.510

# %%
m1_est
# Out:
#     parameter     ci_l         est          ci_h         n_eff    Rhat
# 1   Sigma[1,1]    0.0011020971 0.0012156559 0.0013323734 3454.156 0.9999929
# 2   Sigma[1,2]    0.0004110183 0.0004819447 0.0005606204 2805.941 0.9994784
# 3   Sigma[2,1]    0.0004110183 0.0004819447 0.0005606204 2805.941 0.9994784
# 4   Sigma[2,2]    0.0009280887 0.0010231430 0.0011274067 3371.578 0.9994398
# 5   pi[1]         0.7847533898 0.7988739212 0.8128558103 3304.269 0.9999995
# 6   pi[2]         0.1871441897 0.2011260788 0.2152466102 3304.269 0.9999995
# 7   Omegacor[1,1] 1.0000000000 1.0000000000 1.0000000000      NaN       NaN
# 8   Omegacor[1,2] 0.3795137802 0.4321721594 0.4854591490 2969.383 1.0001666
# 9   Omegacor[2,1] 0.3795137802 0.4321721594 0.4854591490 2969.383 1.0001666
# 10  Omegacor[2,2] 1.0000000000 1.0000000000 1.0000000000 3803.941 0.9989995
# 11  Sigma[1,1]    0.0010303713 0.0011277396 0.0012484174 3269.184 0.9996492
# ...

# %%
m2_est %>% filter(Rhat > 1.1 | n_eff < 200) # 1,3,5
# Out:
#    parameter  ci_l         est          ci_h        n_eff      Rhat
# 1  pi[1]      6.605370e-01 0.6991662549 0.710817574   2.225583  2.994470
# 2  pi[2]      3.764436e-06 0.0001494574 0.068893037   2.011966 13.071478
# 3  pi[3]      5.999313e-02 0.0697107174 0.083764834   3.377649  1.524715
# 4  pi[4]      1.839343e-01 0.2285079972 0.239875061   2.124849  3.921906
# 5  sigmasq[2] 1.313005e-02 0.0148422014 0.016874548  41.831983  1.037874
# 6  sigmasq[3] 2.008804e-02 0.0215898200 0.026467567   2.292048  2.671853
# 7  sigmasq[4] 2.172513e-02 0.0232624385 0.028436133   2.261900  2.796356
# 8  pi[1]      6.097095e-01 0.6258112951 0.667507601   2.271189  2.766719
# 9  pi[2]      5.426323e-02 0.0632998197 0.072949956  29.903794  1.051700
# 10 pi[3]      1.318034e-05 0.0769828608 0.091492528   2.043817  6.549057
# 11 pi[4]      2.228506e-01 0.2355806993 0.285760279   2.140029  3.711458
# 12 sigmasq[1] 2.129537e-02 0.0239611760 0.027458164 167.346340  1.018609
# ...

# %%
m2_est %>% filter(Rhat < 1.1 & n_eff > 200)  # 2, 4, 6, 7
# Out:
#    parameter  ci_l         est          ci_h         n_eff    Rhat
# 1  sigmasq[1] 5.771902e-03 7.680143e-01 2.651499e+01 2001.827 1.0017071
# 2  pi[1]      6.973534e-01 7.075546e-01 7.179211e-01 4065.341 1.0004703
# 3  pi[2]      1.942815e-04 5.704002e-04 1.261138e-03 4148.545 0.9996023
# 4  pi[3]      1.893803e-04 5.599334e-04 1.236438e-03 4382.858 0.9993563
# 5  pi[4]      2.810279e-01 2.912509e-01 3.014651e-01 4002.148 1.0004372
# 6  sigmasq[1] 1.888905e-01 8.452244e-01 1.604358e+01 1952.513 1.0002505
# 7  sigmasq[2] 2.005860e-01 8.887452e-01 1.633153e+01 3496.604 1.0001422
# 8  sigmasq[3] 8.270651e-03 8.765498e-03 9.279912e-03 4245.702 0.9997708
# 9  sigmasq[4] 8.148964e-03 8.619001e-03 9.109849e-03 4968.929 0.9995478
# 10 sigmasq[2] 2.530661e-03 2.981234e-03 2.148186e+08 3997.737 1.0000026
# 11 pi[1]      7.240925e-01 7.338709e-01 7.432333e-01 5779.923 1.0000938
# 12 pi[2]      5.163236e-06 1.290193e-04 6.947406e-04 5564.362 0.9996676
# ...

# %%
ggplot(m1_est %>% filter(), aes(x=fit_params, y=est))
