# %% [markdown]
# ### figure 2 - sex-specific heritability and genetic correlation of biomarkers and other traits

# %%
# load packages and dependencies
require('tidyverse')
require('reshape2')  # for dcast

# %%
# read in all the ss biomarker data
BIOMARKER.DIR <- "../../data/biomarker/"
biomarker_traits <- list.files(BIOMARKER.DIR, pattern="dat_\\D*.RData")

biomarkers <- sapply(biomarker_traits, function(x) strsplit(strsplit(x, "dat_",fixed=TRUE)[[1]][[2]], ".RData")[[1]][[1]])

biomarkers2 <- setdiff(biomarkers , c("arm_fp", "leg_fp", "trunk_fp", "whr"))
biomarkers2
length(biomarkers2) # 35 biomarkers

# column names depend on the dimension
# t(c(trait, dat$dat$N, unlist(m1.pi), unlist(m1.Sigma), unlist(rg), unlist(rg.c$l), unlist(rg.c$u), unlist(h)))
# rg.l and rg.u are the 95% CI for rg
m1.cols <-  c("trait", "n", "pi[1]", "pi[2]", "Sigma[1,1]", "Sigma[1,2]", "Sigma[2,1]", "Sigma[2,2]", "rg", "rg.l", "rg.u", "h.f", "h.m")

biomarker_df <- do.call(rbind, lapply(biomarkers2, function(x) read.table(sprintf("%ssummary_dat_%s_2_.txt", BIOMARKER.DIR, x), sep=" ", header=TRUE)))
colnames(biomarker_df) <- m1.cols
head(biomarker_df)
# Out:
#  [1] "Alanine_aminotransferase"   "Albumin"
#  [3] "Alkaline_phosphatase"       "Apolipoprotein_A"
#  [5] "Apolipoprotein_B"           "Aspartate_aminotransferase"
#  [7] "C_reactive_protein"         "Calcium"
#  [9] "Cholesterol"                "Creatinine_in_urine"
# [11] "Creatinine"                 "Cystatin_C"
# [13] "Direct_bilirubin"           "eGFR"
# [15] "Fasting_glucose"            "Gamma_glutamyltransferase"
# [17] "Glucose"                    "HDL_cholesterol"
# [19] "LDL_direct"                 "Lipoprotein_A"
# [21] "Microalbumin_in_urine"      "Non_albumin_protein"
# [23] "Oestradiol"                 "Phosphate"
# [25] "Potassium_in_urine"         "Rheumatoid_factor"
# [27] "SHBG"                       "Sodium_in_urine"
# [29] "Testosterone"               "Total_bilirubin"
# [31] "Total_protein"              "Triglycerides"
# [33] "Urate"                      "Urea"
# [35] "Vitamin_D"
# [1] 35
#   trait                      n      pi[1]     pi[2]       Sigma[1,1]
# 1 Alanine_aminotransferase   329489 0.9005958 0.099404180 7.900984e-05
# 2 Albumin                    328834 0.9184398 0.081560151 1.051443e-04
# 3 Alkaline_phosphatase       329460 0.9750944 0.024905583 7.987477e-04
# 4 Apolipoprotein_A           328825 0.9601360 0.039863997 3.660458e-04
# 5 Apolipoprotein_B           329484 0.9920862 0.007913833 2.522722e-03
# 6 Aspartate_aminotransferase 329470 0.9461250 0.053875010 2.001315e-04
#   Sigma[1,2]   Sigma[2,1]   Sigma[2,2]   rg        rg.l      rg.u
# 1 0.0000749468 0.0000749468 0.0000828066 0.9266520 0.9089671 0.9434492
# 2 0.0001054654 0.0001054654 0.0001102565 0.9796028 0.9650855 0.9929663
# 3 0.0009167832 0.0009167832 0.0010761253 0.9888571 0.9856582 0.9917516
# 4 0.0003727071 0.0003727071 0.0004004914 0.9734566 0.9668658 0.9795397
# 5 0.0021376278 0.0021376278 0.0018662656 0.9851760 0.9819521 0.9880587
# 6 0.0001953104 0.0001953104 0.0001991978 0.9782311 0.9690145 0.9866551
#   h.f       h.m
# 1        NA        NA
# 2 0.1170386 0.1239111
# 3 0.1229002 0.1578421
# 4 0.1141412 0.1270307
# 5 0.1332828 0.1014390
# 6        NA        NA

# %%
# read in all the other trait data
ALT.DIR <- "../../data/1009/"

summary_files <- list.files(ALT.DIR, pattern="summary_(\\w)*_2_.txt")
alt_traits <- str_replace_all(summary_files, c("summary_dat_"="", "_2_.txt" =""))

alt_df <- do.call(rbind, lapply(summary_files, function(x) read.table(sprintf("%s/%s", ALT.DIR, x), sep=" ", header=TRUE)))
colnames(alt_df) <- m1.cols
head(alt_df)
    

# read in all the error bars now
    
alt_err <- do.call(rbind, lapply(alt_traits, function(trait) read_tsv(sprintf("%sh_err_%s_2_.txt", ALT.DIR, trait))))
# Out:
#   trait    n      pi[1]     pi[2]     Sigma[1,1]   Sigma[1,2]    Sigma[2,1]
# 1 arm_fp   183550 0.5781458 0.4218542 2.186498e-05  6.072976e-06  6.072976e-06
# 2 FEV_FVC  181293 0.8525613 0.1474387 3.504840e+06 -1.561816e+01 -1.561816e+01
# 3 INI20015 183883 0.7177631 0.2822369 5.853551e-05  5.880110e-05  5.880110e-05
# 4 INI20021  99105 0.7705029 0.2294971 1.292828e-02  7.224052e-04  7.224052e-04
# 5 INI20022 178885 0.7979287 0.2020713 2.291604e-05  1.964722e-05  1.964722e-05
# 6 INI20150 183206 0.6558704 0.3441296 2.213115e-05  2.135129e-05  2.135129e-05
#   Sigma[2,2]   rg        rg.l       rg.u      h.f       h.m
# 1 1.179050e-05 0.3782698  0.3488308 0.4064221 0.2603190 0.1727109
# 2 6.703808e+02 0.1906889 -0.7955964 0.9393048       NaN       NaN
# 3 6.192723e-05 0.9766783  0.9670898 0.9854629 0.2494337 0.2555497
# 4 1.017964e-01 0.1650509 -0.5095128 0.7892614 0.1431773 0.6892277
# 5 1.985772e-05 0.9217529  0.8577045 0.9783293 0.1467711 0.1014030
# 6 2.189049e-05 0.9701867  0.9478763 0.9887214 0.2017964 0.1946574
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )

# %%
# fix the fact that the traits have numbers instead of values in the table
alt_err2 <- alt_err %>% 
   mutate(trait=ifelse(trait %in% alt_traits, trait, alt_traits[as.numeric(trait)]))

# %%
# need to read in a key and change the codes
phe_codes <- read_csv("../../data/ListPheCodes.csv")
head(phe_codes)
phe_codes <- phe_codes %>% 
mutate(variable_name=str_replace_all(variable_name, " ", "_")) %>%
mutate(trait=str_replace(trait, "INI", ""))
phe_codes %>% filter(variable_name=="Testosterone")
# Out:
# Parsed with column specification:
# cols(
#   trait = col_character(),
#   category = col_character(),
#   variable_name = col_character(),
#   readable_name = col_character()
# )
#   trait category     variable_name     readable_name
# 1 3140  sex specific pregnant          pregnant
# 2 2724  sex specific menopause         menopause
# 3 3581  sex specific menopause_age     age menopause
# 4 3591  sex specific hysterectomy      hysterectomy
# 5 2934  sex specific oophorectomy      oophorectomy
# 6 3700  sex specific time_since_period time since last menstrual period
#   trait category  variable_name readable_name
# 1 30850 biomarker Testosterone  NA

# %%
alt_df <- alt_df %>% mutate(trait=str_replace(trait,"INI", ""))
alt_err2 <- alt_err2 %>% mutate(trait=str_replace(trait,"INI", ""))

# %%
phe_codes$trait
# Out:
#   [1] "3140"     "2724"     "3581"     "3591"     "2934"     "3700"
#   [7] "3710"     "3720"     "2804"     "3546"     "2178"     "2188"
#  [13] "whr"      "21001"    "50"       "48"       "49"       "4079"
#  [19] "4080"     "20150"    "3063"     "3064"     "FEV_FVC"  "23100"
#  [25] "23116"    "23112"    "23124"    "23120"    "23128"    "23099"
#  [31] "23105"    "23115"    "23111"    "23123"    "23119"    "23127"
#  [37] "23100"    "23101"    "23102"    "23106"    "23107"    "23108"
#  [43] "23109"    "23110"    "trunk_fp" "leg_fp"   "arm_fp"   "46"
#  [49] "47"       "20015"    "20019"    "20021"    "20022"    "20150"
#  [55] "20151"    "21021"    "30000"    "30010"    "30020"    "30030"
#  [61] "30040"    "30050"    "30060"    "30070"    "30080"    "30090"
#  [67] "30100"    "30110"    "30120"    "30130"    "30140"    "30150"
#  [73] "30160"    "30170"    "30180"    "30190"    "30200"    "30210"
#  [79] "30220"    "30230"    "30240"    "30250"    "30260"    "30270"
#  [85] "30280"    "30290"    "30300"    "30500"    "30510"    "30520"
#  [91] "30530"    "30620"    "30600"    "30610"    "30630"    "30640"
#  [97] "30650"    "30710"    "30680"    "30690"    "30700"    "30720"
# [103] "30660"    "30730"    "30740"    "30750"    "30760"    "30770"
# [109] "30780"    "30790"    "30800"    "30810"    "30820"    "30830"
# [115] "30850"    "30840"    "30860"    "30870"    "30880"    "30670"
# [121] "30890"    "30510"

# %%
alt_df2 <- right_join(phe_codes %>% select(trait, category, variable_name), alt_df) %>% select(-h.f, -h.m) 
alt_err2 <- right_join(phe_codes %>% select(trait, category, variable_name), alt_err2)
head(alt_err2)
head(alt_df2)
# Out:
# Joining, by = "trait"
# Joining, by = "trait"
#   trait  category         variable_name int    sex value
# 1 arm_fp fat distribution arm_fat_ratio up     hf  0.2586310
# 2 arm_fp fat distribution arm_fat_ratio low    hf  0.2578651
# 3 arm_fp fat distribution arm_fat_ratio center hf  0.2592817
# 4 arm_fp fat distribution arm_fat_ratio up     hm  0.1742181
# 5 arm_fp fat distribution arm_fat_ratio low    hm  0.1705815
# 6 arm_fp fat distribution arm_fat_ratio center hm  0.1775808
#   trait   category
# 1 arm_fp  fat distribution
# 2 FEV_FVC breathing
# 3 20015   anthropometric traits
# 4 20021   hearing test
# 5 20022   anthropometric traits
# 6 20150   breathing
#   variable_name                                     n      pi[1]     pi[2]
# 1 arm_fat_ratio                                     183550 0.5781458 0.4218542
# 2 FEV_FVC                                           181293 0.8525613 0.1474387
# 3 Sitting_height                                    183883 0.7177631 0.2822369
# 4 Speech-reception-threshold_(SRT)_estimate_(right)  99105 0.7705029 0.2294971
# 5 Birth_weight                                      178885 0.7979287 0.2020713
# 6 FEV-1                                             183206 0.6558704 0.3441296
#   Sigma[1,1]   Sigma[1,2]    Sigma[2,1]    Sigma[2,2]   rg        rg.l
# 1 2.186498e-05  6.072976e-06  6.072976e-06 1.179050e-05 0.3782698  0.3488308
# 2 3.504840e+06 -1.561816e+01 -1.561816e+01 6.703808e+02 0.1906889 -0.7955964
# 3 5.853551e-05  5.880110e-05  5.880110e-05 6.192723e-05 0.9766783  0.9670898
# 4 1.292828e-02  7.224052e-04  7.224052e-04 1.017964e-01 0.1650509 -0.5095128
# 5 2.291604e-05  1.964722e-05  1.964722e-05 1.985772e-05 0.9217529  0.8577045
# 6 2.213115e-05  2.135129e-05  2.135129e-05 2.189049e-05 0.9701867  0.9478763
#   rg.u
# 1 0.4064221
# 2 0.9393048
# 3 0.9854629
# 4 0.7892614
# 5 0.9783293
# 6 0.9887214

# %%
setdiff(as.character(biomarker_df$trait), phe_codes$variable_name)
setdiff(filter(phe_codes, category=="biomarker")$variable_name,as.character(biomarker_df$trait))

## TODO: looks like we're missing hbA1C and IGF-1 <-- go back and redo these!

length(intersect(as.character(biomarker_df$trait), phe_codes$variable_name)) # 32

# added this one: 30510, biomarker, Creatinine_in_urine, NA; fixed CRP

## TODO: what is going on w "Fasting_glucose", "eGFR", "Non_albumin_protein" <-- are these derived?
##  these are phenotypes we somehow have but didn't know abt?
##  consider the statin-adjusted too
# Out:
# [1] "eGFR"                "Fasting_glucose"     "Non_albumin_protein"
# [1] "Glycated_haemoglobin_(HbA1c)" "IGF-1"
# [1] 32

# %%
biomarker_df2 <- right_join(phe_codes %>% select(trait, category, variable_name), 
                            biomarker_df %>% rename(variable_name=trait))  %>%
mutate(category="biomarker", trait=ifelse(is.na(trait), variable_name, trait))  %>% select(-h.f, -h.m) 

head(biomarker_df2)
# Out:
# Joining, by = "variable_name"
# Warning message:
# “Column `variable_name` joining character vector and factor, coercing into character vector”
#   trait category  variable_name              n      pi[1]     pi[2]
# 1 30620 biomarker Alanine_aminotransferase   329489 0.9005958 0.099404180
# 2 30600 biomarker Albumin                    328834 0.9184398 0.081560151
# 3 30610 biomarker Alkaline_phosphatase       329460 0.9750944 0.024905583
# 4 30630 biomarker Apolipoprotein_A           328825 0.9601360 0.039863997
# 5 30640 biomarker Apolipoprotein_B           329484 0.9920862 0.007913833
# 6 30650 biomarker Aspartate_aminotransferase 329470 0.9461250 0.053875010
#   Sigma[1,1]   Sigma[1,2]   Sigma[2,1]   Sigma[2,2]   rg        rg.l
# 1 7.900984e-05 0.0000749468 0.0000749468 0.0000828066 0.9266520 0.9089671
# 2 1.051443e-04 0.0001054654 0.0001054654 0.0001102565 0.9796028 0.9650855
# 3 7.987477e-04 0.0009167832 0.0009167832 0.0010761253 0.9888571 0.9856582
# 4 3.660458e-04 0.0003727071 0.0003727071 0.0004004914 0.9734566 0.9668658
# 5 2.522722e-03 0.0021376278 0.0021376278 0.0018662656 0.9851760 0.9819521
# 6 2.001315e-04 0.0001953104 0.0001953104 0.0001991978 0.9782311 0.9690145
#   rg.u
# 1 0.9434492
# 2 0.9929663
# 3 0.9917516
# 4 0.9795397
# 5 0.9880587
# 6 0.9866551

# %%
biomarker_err <- do.call(rbind, lapply(biomarkers2, function(trait) 
    read_tsv(sprintf("%sh_err_%s_2_.txt", BIOMARKER.DIR, trait))))
head(biomarker_err)
length(unique(biomarker_err$trait))
length(biomarkers2)
biomarker_err2 <- biomarker_err %>% mutate(trait=biomarkers2[trait])
head(biomarker_err2)
# Out:
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_character()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_character()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_character()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
# Parsed with column specification:
# cols(
#   trait = col_integer(),
#   int = col_character(),
#   sex = col_character(),
#   value = col_double()
# )
#   trait int    sex value
# 1 1     up     hf  NA
# 2 1     low    hf  NA
# 3 1     center hf  NA
# 4 1     up     hm  NA
# 5 1     low    hm  NA
# 6 1     center hm  NA
# [1] 35
# [1] 35
#   trait                    int    sex value
# 1 Alanine_aminotransferase up     hf  NA
# 2 Alanine_aminotransferase low    hf  NA
# 3 Alanine_aminotransferase center hf  NA
# 4 Alanine_aminotransferase up     hm  NA
# 5 Alanine_aminotransferase low    hm  NA
# 6 Alanine_aminotransferase center hm  NA

# %%
biomarker_err_df <- right_join(phe_codes %>% select(trait, category, variable_name), biomarker_err2 %>% 
                               rename(variable_name=trait))
biomarker_err_df2 <- biomarker_err_df %>% mutate( category="biomarker", 
                            trait=ifelse(is.na(trait), variable_name, trait)) 
#biomarker_err_df[is.na(category)]$category <- "biomarker"
#head(biomarker_err_df)
# Out:
# Joining, by = "variable_name"

# %%
biomarker_err2 %>% filter(is.na(value)) 

# TODO: these traits  do not have heritability estimates - what is going on?
# Out:
#    trait                      int    sex value
# 1  Alanine_aminotransferase   up     hf  NA
# 2  Alanine_aminotransferase   low    hf  NA
# 3  Alanine_aminotransferase   center hf  NA
# 4  Alanine_aminotransferase   up     hm  NA
# 5  Alanine_aminotransferase   low    hm  NA
# 6  Alanine_aminotransferase   center hm  NA
# 7  Aspartate_aminotransferase up     hf  NA
# 8  Aspartate_aminotransferase low    hf  NA
# 9  Aspartate_aminotransferase center hf  NA
# 10 Aspartate_aminotransferase up     hm  NA
# 11 Aspartate_aminotransferase low    hm  NA
# 12 Aspartate_aminotransferase center hm  NA
# 13 SHBG                       up     hf  NA
# 14 SHBG                       low    hf  NA
# 15 SHBG                       center hf  NA
# 16 SHBG                       up     hm  NA
# 17 SHBG                       low    hm  NA
# 18 SHBG                       center hm  NA

# %%
# write out all the aggregated files

biomarker_err_wide <- biomarker_err_df2 %>% 
mutate("h_type"=paste(sex, substr(int, 1, 1), sep=".")) %>% 
select(-int, -sex) %>% spread(h_type, value) 


alt_err_wide <- alt_err2 %>% 
mutate("h_type"=paste(sex, substr(int, 1, 1), sep=".")) %>% 
select(-int, -sex) %>% spread(h_type, value)

# %%
head(alt_err_wide)
# Out:
#   trait category
# 1 20015 anthropometric traits
# 2 20021 hearing test
# 3 20022 anthropometric traits
# 4 20150 breathing
# 5 20150 breathing
# 6 21001 anthropometric traits
#   variable_name                                             hf.c      hf.l
# 1 Sitting_height                                            0.2497530 0.2413600
# 2 Speech-reception-threshold_(SRT)_estimate_(right)               NaN       NaN
# 3 Birth_weight                                              0.1465155 0.1218797
# 4 FEV-1                                                     0.1996084 0.1927295
# 5 Forced_expiratory_volume_in_1-second_(FEV1),_Best_measure 0.1996084 0.1927295
# 6 BMI                                                       0.1676359 0.1693271
#   hf.u      hm.c       hm.l       hm.u
# 1 0.2570314 0.25418795 0.24996276 0.2618516
# 2 0.2273366        NaN        NaN 0.2409643
# 3 0.1732375 0.09608062 0.09142905 0.1184361
# 4 0.2030422 0.20038504 0.19240393 0.1978086
# 5 0.2030422 0.20038504 0.19240393 0.1978086
# 6 0.1597486 0.17258861 0.18488401 0.1663207

# %%
alt_full <- alt_df2 %>% rename(rg.c=rg) %>% 
full_join(select(alt_err_wide, c(-category, -variable_name)), by="trait") %>% unique()


biomarker_full <- biomarker_df2 %>% rename(rg.c=rg) %>% 
full_join(select(biomarker_err_wide, c(-category, -variable_name)), by="trait") %>% unique()

m1_full <- rbind(biomarker_full, alt_full)
unique(m1_full$category)
m1_full$category[m1_full$category=="fat distribution"] <- "anthropometric"
m1_full$category[m1_full$category=="anthropometric traits"] <- "anthropometric"
m1_full$category[m1_full$category=="urinalysis"] <- "biomarker"
m1_full$category[m1_full$category %in% c("breathing", "hearing test", "lab test", "physical test")] <- "other"

write_csv(biomarker_full, "../../data/aggreg_results_1011/m1_biomarker.txt")
write_csv(m1_full, "../../data/aggreg_results_1011/m1_full.txt")
# Out:
# [1] "biomarker"             "fat distribution"      "breathing"
# [4] "anthropometric traits" "hearing test"          "lab test"
# [7] "blood composition"     "urinalysis"            "physical test"

# %% [markdown]
# ### CHECKING FAILED RUNS

# %%
m1_full %>% filter(str_detect(variable_name, "Creatinine"))
# Out:
#   trait category  variable_name                   n      pi[1]     pi[2]
# 1 30510 biomarker Creatinine_in_urine             329268 0.6402277 0.3597723
# 2 30700 biomarker Creatinine                      329544 0.8339473 0.1660527
# 3 30510 biomarker Creatinine_(enzymatic)_in_urine 183190 0.5170227 0.4829773
# 4 30510 biomarker Creatinine_in_urine             183190 0.5170227 0.4829773
#   Sigma[1,1]   Sigma[1,2]   Sigma[2,1]   Sigma[2,2]   rg.c      rg.l
# 1 9.050822e-06 7.527736e-06 7.527736e-06 7.368378e-06 0.9226256 0.8651214
# 2 8.934142e-05 7.510175e-05 7.510175e-05 7.300339e-05 0.9299690 0.9171573
# 3 6.122693e-06 4.670366e-06 4.670366e-06 4.489249e-06 0.8920068 0.8223559
# 4 6.122693e-06 4.670366e-06 4.670366e-06 4.489249e-06 0.8920068 0.8223559
#   rg.u      hf.c              hf.l               hf.u
# 1 0.9772823 0.190841869215111 0.181643869655869  0.201619245815422
# 2 0.9424915 0.113895381558266 0.0949629305435183 0.127931423588284
# 3 0.9577608 0.129121192415841 0.116351756433478  0.082375887655424
# 4 0.9577608 0.129121192415841 0.116351756433478  0.082375887655424
#   hm.c               hm.l               hm.u
# 1 0.165678216601272  0.154751577613459  0.168664995207675
# 2 0.0993181432104183 0.0805893662073851 0.110200597191314
# 3 0.0998220291055011 0.0932044816560141 0.0579010300689187
# 4 0.0998220291055011 0.0932044816560141 0.0579010300689187

# %%
m1_full %>% filter(str_detect(variable_name, "ucose"))
# Out:
#   trait           category  variable_name   n      pi[1]     pi[2]
# 1 Fasting_glucose biomarker Fasting_glucose 294185 0.9989787 0.001021267
# 2 30740           biomarker Glucose         294185 0.9988815 0.001118469
#   Sigma[1,1]  Sigma[1,2]  Sigma[2,1]  Sigma[2,2]  rg.c      rg.l      rg.u
# 1 0.003190613 0.001831687 0.001831687 0.002699640 0.6796259 0.1988573 0.9507319
# 2 0.003224985 0.001869219 0.001869219 0.002611523 0.6975267 0.2256960 0.9611060
#   hf.c                hf.l                 hf.u
# 1 0.00226210599527676 8.62535799100885e-05 0.0243654647577309
# 2 0.00218898540341594 7.54833962524066e-05 0.0263961196116115
#   hm.c                hm.l                 hm.u
# 1 0.00512427252942116 0.000256031703246281 0.0101892982806938
# 2 0.00510077684733174 0.00021252452653289  0.0220505219230238

# %%
 

# which are NAs?
# which have crazy CIs?
# do we have an intuition for why this is?
rg_bad <- m1_full %>% filter(rg.u > 1 | rg.l <  0) %>% select(variable_name)
rg_bad$variable_name
h_bad <- m1_full[apply(m1_full, 1, function(x) any(is.na(x)) | any(is.na(x))),] %>% select(variable_name)
h_bad$variable_name

    
to.remove.var_name <- c("Potassium_in_urine", "Microalbumin_in_urine", "Sodium_in_urine", "FEV_FVC", 
                    "Speech-reception-threshold_(SRT)_estimate_(right)", "Nucleated_red_blood_cell_count",
                   "Nucleated_red_blood_cell_percentage", "Pulse_wave_Arterial_Stiffness_index")
to.remove.trait <- "30510"
# remove ALL THREE creatinine in urine (trait 30510)
# Out:
#  [1] "Oestradiol"
#  [2] "Potassium_in_urine"
#  [3] "Rheumatoid_factor"
#  [4] "FEV_FVC"
#  [5] "Speech-reception-threshold_(SRT)_estimate_(right)"
#  [6] "Pulse_wave_Arterial_Stiffness_index"
#  [7] "Nucleated_red_blood_cell_count"
#  [8] "Nucleated_red_blood_cell_percentage"
#  [9] "Microalbumin_in_urine"
# [10] "Sodium_in_urine"
# [1] "Alanine_aminotransferase"   "Aspartate_aminotransferase"
# [3] "SHBG"

# %%
m1_full %>% 
filter(trait %in% m1_full[duplicated(m1_full$trait),]$trait) %>% 
arrange(trait)
# hmm... mb try re-running the urinalysis ones?

duplicates <- c("Forced_expiratory_volume_in_1-second_(FEV1),_Best_measure", "whole_body_fat_mass")
# Out:
#    trait category
# 1  20150 other
# 2  20150 other
# 3  23100 anthropometric
# 4  23100 anthropometric
# 5  30500 biomarker
# 6  30500 biomarker
# 7  30510 biomarker
# 8  30510 biomarker
# 9  30510 biomarker
# 10 30520 biomarker
# 11 30520 biomarker
# 12 30530 biomarker
# 13 30530 biomarker
#    variable_name                                             n      pi[1]
# 1  FEV-1                                                     183206 0.6558704
# 2  Forced_expiratory_volume_in_1-second_(FEV1),_Best_measure 183206 0.6558704
# 3  total_fat_mass                                            183281 0.5273115
# 4  whole_body_fat_mass                                       183281 0.5273115
# 5  Microalbumin_in_urine                                     320385 0.9999630
# 6  Microalbumin_in_urine                                     174493 0.9999784
# 7  Creatinine_in_urine                                       329268 0.6402277
# 8  Creatinine_(enzymatic)_in_urine                           183190 0.5170227
# 9  Creatinine_in_urine                                       183190 0.5170227
# 10 Potassium_in_urine                                        329250 0.9712071
# 11 Potassium_in_urine                                        183132 0.7025117
# 12 Sodium_in_urine                                           329253 0.5626205
# 13 Sodium_in_urine                                           183173 0.7327356
#    pi[2]        Sigma[1,1]   Sigma[1,2]    Sigma[2,1]    Sigma[2,2]   rg.c
# 1  3.441296e-01 2.213115e-05  2.135129e-05  2.135129e-05 2.189049e-05 0.9701867
# 2  3.441296e-01 2.213115e-05  2.135129e-05  2.135129e-05 2.189049e-05 0.9701867
# 3  4.726885e-01 1.989816e-05  1.845296e-05  1.845296e-05 1.988078e-05 0.9278850
# 4  4.726885e-01 1.989816e-05  1.845296e-05  1.845296e-05 1.988078e-05 0.9278850
# 5  3.699275e-05 5.823488e-02  6.249172e-02  6.249172e-02 7.979649e-02 0.9339202
# 6  2.161246e-05 1.370042e+00  1.673807e-01  1.673807e-01 8.442342e-01 0.3854148
# 7  3.597723e-01 9.050822e-06  7.527736e-06  7.527736e-06 7.368378e-06 0.9226256
# 8  4.829773e-01 6.122693e-06  4.670366e-06  4.670366e-06 4.489249e-06 0.8920068
# 9  4.829773e-01 6.122693e-06  4.670366e-06  4.670366e-06 4.489249e-06 0.8920068
# 10 2.879287e-02 6.633115e+02 -5.678075e+00 -5.678075e+00 1.953260e+03 0.1665715
# 11 2.974883e-01 2.314793e-05  1.789485e-05  1.789485e-05 3.789269e-05 0.7740901
# 12 4.373795e-01 7.344987e-06  6.582312e-06  6.582312e-06 6.656168e-06 0.9419830
# 13 2.672644e-01 1.797069e+04 -8.601309e+00 -8.601309e+00 5.591069e+02 0.4636567
#    rg.l       rg.u      hf.c                 hf.l
# 1   0.9478763 0.9887214 0.199608367227411    0.192729493400822
# 2   0.9478763 0.9887214 0.199608367227411    0.192729493400822
# 3   0.9082902 0.9468647 0.1837895810187      0.184459622677743
# 4   0.9082902 0.9468647 0.1837895810187      0.184459622677743
# 5   0.6773934 0.9971497 0.000912972988053936 0.00014320190014442
# 6  -0.5453468 0.9562869 0.0020246497872511   8.37733374140755e-05
# 7   0.8651214 0.9772823 0.190841869215111    0.181643869655869
# 8   0.8223559 0.9577608 0.129121192415841    0.116351756433478
# 9   0.8223559 0.9577608 0.129121192415841    0.116351756433478
# 10 -0.7901555 0.9849196 NaN                  NaN
# 11  0.5657486 0.9293296 0.10542197114841     NaN
# 12  0.8825132 0.9887578 0.103604917755833    0.0906814645286503
# 13 -0.7596158 0.9677341 NaN                  NaN
#    hf.u               hm.c                 hm.l
# 1  0.203042177869689  0.200385037910896    0.192403925677758
# 2  0.203042177869689  0.200385037910896    0.192403925677758
# 3  0.17747595514077   0.178827306735461    0.181968281123947
# 4  0.17747595514077   0.178827306735461    0.181968281123947
# 5  0.0058976049821734 0.000850722943038608 0.00038245974654104
# 6  0.0841677590774241 0.00142229922905728  0.000102121836855847
# 7  0.201619245815422  0.165678216601272    0.154751577613459
# 8  0.082375887655424  0.0998220291055011   0.0932044816560141
# 9  0.082375887655424  0.0998220291055011   0.0932044816560141
# 10 NaN                NaN                  NaN
# 11 0.25509621221722   0.104826735349193    NaN
# 12 0.0998178165500991 0.0972441476448655   0.0845789631618035
# 13 0.999992460797336  NaN                  NaN
#    hm.u
# 1  0.197808635804171
# 2  0.197808635804171
# 3  0.177686978168077
# 4  0.177686978168077
# 5  0.00628990073609214
# 6  0.0488820368652513
# 7  0.168664995207675
# 8  0.0579010300689187
# 9  0.0579010300689187
# 10 NaN
# 11 0.405963946660188
# 12 0.0865165800833321
# 13 0.996961053540276

# %%
biomarkers_poor <- c("Oestradiol", "Rheumatoid_factor", "Glucose", "Fasting_glucose") #"SHBG? Aminotransferase? - should we remove?


m1_filt <- m1_full %>% 
filter(!variable_name %in% to.remove.var_name) %>% 
filter( trait != to.remove.trait) %>% 
filter(!variable_name %in% duplicates) %>%
filter(!variable_name %in% biomarkers_poor)



length(m1_filt$trait)
# Out:
# [1] 93

# %%
bad_ci <- m1_filt %>% filter(
hf.u < hf.c |
hf.c < hf.l |
hm.u < hm.c |
hm.c < hm.l) 
dim(bad_ci)
bad_ci2 <- bad_ci %>% filter(!hf.u < hf.l & ! hm.u < hm.l)
bad_ci2
# Out:
# [1] 26 19
#   trait    category       variable_name        n      pi[1]     pi[2]
# 1 arm_fp   anthropometric arm_fat_ratio        183550 0.5781458 0.4218542
# 2 20150    other          FEV-1                183206 0.6558704 0.3441296
# 3 23105    other          basal_metabolic_rate 183442 0.6175748 0.3824252
# 4 23109    anthropometric impedance_of_arm_(r) 183300 0.5918276 0.4081724
# 5 23110    anthropometric impedance_of_arm_(l) 183299 0.5867658 0.4132342
# 6 49       anthropometric hip_circum           183405 0.5668454 0.4331546
# 7 trunk_fp anthropometric trunk_fatio_ratio    183424 0.7350891 0.2649109
#   Sigma[1,1]   Sigma[1,2]   Sigma[2,1]   Sigma[2,2]   rg.c      rg.l
# 1 2.186498e-05 6.072976e-06 6.072976e-06 1.179050e-05 0.3782698 0.3488308
# 2 2.213115e-05 2.135129e-05 2.135129e-05 2.189049e-05 0.9701867 0.9478763
# 3 3.340237e-05 3.336898e-05 3.336898e-05 3.652396e-05 0.9554062 0.9423411
# 4 2.480340e-05 2.393872e-05 2.393872e-05 2.657849e-05 0.9324196 0.9140389
# 5 2.419955e-05 2.323308e-05 2.323308e-05 2.646070e-05 0.9181956 0.9006303
# 6 2.045741e-05 1.953125e-05 1.953125e-05 2.157485e-05 0.9297960 0.9096705
# 7 4.090987e-05 1.103905e-05 1.103905e-05 1.429824e-05 0.4565388 0.4250263
#   rg.u      hf.c              hf.l              hf.u
# 1 0.4064221 0.259281708444195 0.257865094798673 0.258630999466075
# 2 0.9887214 0.199608367227411 0.192729493400822 0.203042177869689
# 3 0.9689240 0.220343676399383 0.213850814530616 0.223502795077791
# 4 0.9510890 0.199533020339464 0.196470970152935 0.199814868924257
# 5 0.9359487 0.19727610966879  0.195890864219694 0.199028249138055
# 6 0.9497298 0.190952654188512 0.189144045589904 0.192179060869573
# 7 0.4893679 0.298209512231087 0.284595446056247 0.309709925277082
#   hm.c              hm.l              hm.u
# 1 0.177580760387546 0.170581508505368 0.174218147744253
# 2 0.200385037910896 0.192403925677758 0.197808635804171
# 3 0.234735373529688 0.238011992571594 0.243672429692366
# 4 0.211127699712967 0.21174969533827  0.213300919555627
# 5 0.216300479688259 0.211212413270414 0.214258305977282
# 6 0.200142970212903 0.197628283384233 0.198998048134294
# 7 0.139248979375287 0.127463794239717 0.138471158826144

# %% [markdown]
# ### PLOTTING NOW

# %%
# what are the pis ?
m1_filt%>% filter(`pi[1]` > 0.99) # should we remove these?
# Out:
#   trait category  variable_name    n      pi[1]     pi[2]        Sigma[1,1]
# 1 30640 biomarker Apolipoprotein_B 329484 0.9920862 0.0079138333 0.002522722
# 2 30660 biomarker Direct_bilirubin 328320 0.9978469 0.0021530846 0.007684011
# 3 30780 biomarker LDL_direct       329644 0.9915960 0.0084040261 0.001728055
# 4 30790 biomarker Lipoprotein_A    327886 0.9991571 0.0008428977 0.064338434
# 5 30840 biomarker Total_bilirubin  329427 0.9960614 0.0039385611 0.005889969
#   Sigma[1,2]  Sigma[2,1]  Sigma[2,2]  rg.c      rg.l      rg.u
# 1 0.002137628 0.002137628 0.001866266 0.9851760 0.9819521 0.9880587
# 2 0.007741908 0.007741908 0.007892636 0.9941318 0.9920508 0.9959656
# 3 0.001328757 0.001328757 0.001083425 0.9711215 0.9655867 0.9765805
# 4 0.062596948 0.062596948 0.061489916 0.9952256 0.9931017 0.9968182
# 5 0.005808100 0.005808100 0.005743549 0.9986011 0.9977788 0.9993240
#   hf.c               hf.l               hf.u               hm.c
# 1 0.132956880928322  0.124094482039976  0.150844840302453  0.100184661256414
# 2 0.0479094149740762 0.0421179825323639 0.0624710916725318 0.0582610379836537
# 3 0.12217829233756   0.107812352771679  0.137723667855193  0.0803397935723309
# 4 0.0611015784755601 0.0454902716637117 0.078848807309575  0.0542295196318219
# 5 0.101054298714931  0.0957089370238033 0.120467903922402  0.0989754317929892
#   hm.l               hm.u
# 1 0.0924670647639754 0.115243522315838
# 2 0.0501142988269018 0.0725890374192209
# 3 0.0733239878907961 0.0920282277709176
# 4 0.04170600655446   0.0737232090051959
# 5 0.095324693249614  0.11923211401574

# %%
ggplot(m1_filt, aes(x=`pi[1]`, y=`rg.c`))+geom_point()
# Out:
# plot without title

# %%
ggplot(m1_filt, aes(x=`pi[1]`))+geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
# plot the pis
# plot the genetic correlations

m1_filt <- m1_filt %>% mutate(variable_name=str_replace_all(variable_name, "_", " "))
ggplot(m1_filt, aes(x=variable_name, y=rg.c))+geom_errorbar(aes(ymin=rg.l, ymax=rg.u)) + 
theme(axis.text.x=element_text(angle=90,hjust=1)) +ylab("Genetic Correlation")+xlab("Trait") + 
facet_grid(. ~ category,  scales="free", space="free")
# Out:
# plot without title

# %%
filter(m1_filt, category=="biomarker") %>% select(variable_name) %>% unique() 
ggplot(filter(m1_filt, category=="biomarker"), aes(x=variable_name, y=rg.c))+geom_errorbar(aes(ymin=rg.l, ymax=rg.u)) + 
theme(axis.text.x=element_text(angle=90,hjust=1,  vjust=0.5)) +ylab("Genetic Correlation")+xlab("Trait") + 
facet_grid(. ~ category,  scales="free", space="free")
# Out:
#    variable_name
# 1  Alanine aminotransferase
# 2  Albumin
# 3  Alkaline phosphatase
# 4  Apolipoprotein A
# 5  Apolipoprotein B
# 6  Aspartate aminotransferase
# 7  C reactive protein
# 8  Calcium
# 9  Cholesterol
# 10 Creatinine
# 11 Cystatin C
# 12 Direct bilirubin
# 13 eGFR
# 14 Gamma glutamyltransferase
# 15 HDL cholesterol
# 16 LDL direct
# 17 Lipoprotein A
# 18 Non albumin protein
# 19 Phosphate
# 20 SHBG
# 21 Testosterone
# 22 Total bilirubin
# 23 Total protein
# 24 Triglycerides
# 25 Urate
# 26 Urea
# 27 Vitamin D
# plot without title

# %%
m1_full2 <- m1_filt %>% select(variable_name, category, c('hf.c','hm.c', 'hf.l', 'hf.u' ,'hm.l' ,'hm.u')) %>% 
gather(key="h_type", value="val", -variable_name, -category) 
m1_full2$sex <-sapply(m1_full2$h_type, function(x) strsplit(as.character(x), ".", fixed=TRUE)[[1]][[1]])
m1_full2$int <- sapply(m1_full2$h_type, function(x) strsplit(as.character(x), ".", fixed=TRUE)[[1]][[2]])
m1_full3 <- m1_full2 %>% select(-h_type) %>% unique() %>% filter(!is.na(val)) %>% mutate(val=as.numeric(val))

# %%
m1_full4 <- dcast(m1_full3, variable_name + category + sex ~ int, value.var="val", fun.aggregate = min, na.rm = TRUE)
# Out:
# Warning message in .fun(.value[0], ...):
# “no non-missing arguments to min; returning Inf”

# %%
herit_df <- m1_full4 %>% rename(mid=c, low=l, up=u)  %>% 
mutate(sex=ifelse(sex=="hf", "female", ifelse(sex=="hm", "male", NA))) %>%
mutate(variable_name=str_replace_all(variable_name, "_", " "))

# %%
ggplot(filter(herit_df, category=="biomarker"), aes(x=variable_name, y=mid, fill=sex))+
geom_bar(stat="identity", position=position_dodge())+
geom_errorbar(aes(ymin=low, ymax=up), position=position_dodge(0.9), color="black", width=0.5) + 
theme(axis.text.x=element_text(angle=90,hjust=1, vjust=0.5),
     axis.title.x = element_text(margin = margin(t = 0, r = 0, b = 10, l = 0))) +ylab("Heritability")+xlab("Trait") + 
facet_grid(. ~ category,  scales="free", space="free")
# Out:
# plot without title

# %%
ggplot(filter(herit_df, category=="blood composition"), aes(x=variable_name, y=mid, fill=sex))+
geom_bar(stat="identity", position=position_dodge())+
geom_errorbar(aes(ymin=low, ymax=up), position=position_dodge(0.9), color="black", width=0.5) + 
theme(axis.text.x=element_text(angle=90,hjust=1, vjust=1)) +ylab("Heritability")+xlab("Trait") + 
facet_grid(. ~ category,  scales="free", space="free")
# Out:
# plot without title

# %%
ggplot(filter(herit_df, category=="anthropometric"), aes(x=variable_name, y=mid, fill=sex))+
geom_bar(stat="identity", position=position_dodge())+
geom_errorbar(aes(ymin=low, ymax=up), position=position_dodge(0.9), color="black", width=0.5) + 
theme(axis.text.x=element_text(angle=90,hjust=1)) +ylab("Heritability")+xlab("Trait") + 
facet_grid(. ~ category,  scales="free", space="free")
# Out:
# plot without title

# %%
ggplot(filter(herit_df, category=="other"), aes(x=variable_name, y=mid, fill=sex))+
geom_bar(stat="identity", position=position_dodge())+
geom_errorbar(aes(ymin=low, ymax=up), position=position_dodge(0.9), color="black", width=0.5) + 
theme(axis.text.x=element_text(angle=90,hjust=1)) +ylab("Heritability")+xlab("Trait") + 
facet_grid(. ~ category,  scales="free", space="free")
# Out:
# plot without title

# %%
# plot the heritability

ggplot(herit_df, aes(x=variable_name, y=mid, fill=sex))+
geom_bar(stat="identity", position=position_dodge())+
geom_errorbar(aes(ymin=low, ymax=up), position=position_dodge(0.9), color="black", width=0.5) + 
theme(axis.text.x=element_text(angle=90,hjust=1)) +ylab("Heritability")+xlab("Trait") + 
facet_grid(. ~ category,  scales="free", space="free")
# Out:
# plot without title

# %%
# what is missing? what are we suspicious of?

# find all the ones with weird h.f / r.g confidence intervals
#   what is going on here?
